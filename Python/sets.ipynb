# %% [markdown]
# **Sets**
#
# 1.Sets are a type of
# collection like lists, tuples storing mixed data
#
# 2.Sets are enclosed within curly brackets and elements are written as comma-separated
#
# 3.Sets are unordered
#
# 4.Sets does not allow duplicates

# %%
list1 = [1,2,3,4,5,6,5,7,2,2,2,3]

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 12

# %%
set1 = set(list1)

# %%
len(set1)
# Out:
# 7

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
list_2 = ['A','B','C','A','B','C','A','B','C','A','B','C','D','E']

# %%
set2 = set(list_2)

# %%
set2
# Out:
# {'A', 'B', 'C', 'D', 'E'}

# %%
len(set2)
# Out:
# 5

# %%
set3 = {1,2,3,4,5}

# %%
len(set3)
# Out:
# 5

# %%
set3.add("India")
set3
# Out:
# {1, 2, 3, 4, 5, 'India'}

# %%
print(len(set3))
# Out:
# 6

# %%
set3.remove('India')

# %%
set3
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# **Set Operations**

# %%
A = {0,2,4,6,8}
B = {1,2,3,4,5}

# %%
A|B  #UNION
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8}

# %%
print(A.union(B))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8}

# %%
print(len(A.union(B)))
# Out:
# 8

# %%
print(A&B) #INTERSECTION
# Out:
# {2, 4}

# %%
print(A-B) #DIFFERENCE
# Out:
# {0, 8, 6}

# %%
print(A.difference(B))
# Out:
# {0, 8, 6}

# %%
print(A^B) #symmetric difference -> uncommon elements between two sets
# Out:
# {0, 1, 3, 5, 6, 8}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Why do we use Sets?
# Let’s take a look at an example to understand this better:
#
# Let’s say you have a huge list that contains student grades:
#
# Grades = ['A', 'A', 'B', 'C', 'D', 'B', 'B', 'C', 'D', 'E', 'C', 'C', 'A', 'B', 'F', 'D', 'C', 'B', 'C', 'A', 'B', 'F', 'B', 'A', 'E', 'B', 'B', 'C', 'D'...]
#
# You want to identify distinct grades allotted to students. Obviously, you cannot check every element of this list; instead, we make use of sets which gets our job done here.

# %%
Grades = ['A', 'A', 'B', 'C', 'D', 'B', 'B', 'C', 'D', 'E', 'C', 'C', 'A', 'B', 'F', 'D', 'C', 'B', 'C', 'A', 'B', 'F', 'B', 'A', 'E', 'B', 'B', 'C', 'D']

# %%
set(Grades)
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %% [markdown]
# **Practice Codes**
#
# Description Let’s say you have two lists A and B. Identify the elements which are common in the two lists A and B and return them in a sorted manner. For example
#
# Sample Input :
# A = [5,1,3,4,4,5,6,7]
#
# B = [3,3,5,5, 1 ,7 ,2]
#
# Sample Output:
# [1,3,5,7]

# %%
A = [5,1,3,4,4,5,6,7]
B = [3,3,5,5, 1 ,7 ,2]
setA = set(A)
setB = set(B)
common_set = setA & setB
print(common_set)
print(sorted(common_set))
# Out:
# {1, 3, 5, 7}
# [1, 3, 5, 7]

# %%
#Question 2

nums = set([1,1,2,3,3,3,4])
print(len(nums))
# Out:
# 4

# %%
#Question 3

A = {1,2,3,4,5,6}
B = {0,1,2,10,11}

# %%
A.intersection(B)
# Out:
# {1, 2}

# %%
A.union(B)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 10, 11}

# %%
## Find the output
(A.union(B)).difference(A.intersection(B))
# Out:
# {0, 3, 4, 5, 6, 10, 11}
