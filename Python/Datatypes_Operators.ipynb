# %%
name = 'mike'
print(name)
# Out:
# mike

# %%
type(name)
# Out:
# str

# %%
name = input('enter your name')
print('hello', name)
# Out:
# enter your nameRahish
# hello Rahish

# %%
type(name)
# Out:
# str

# %%
name = input('enter your name: ')
print('welcome', name)
# Out:
# enter your name: Pranav
# welcome Pranav

# %%
name = input('Name:')
print('How are you, ', name)
# Out:
# Name:Vijay
# How are you,  Vijay

# %%
name = input('name:')
print('Hey,', name)
# Out:
# name:Pankaj
# Hey, Pankaj

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# **Typecasting**

# %%
accuracy = 91.2

# %%
print(accuracy)
print(type(accuracy))
# Out:
# 91.2
# <class 'float'>

# %%
int(accuracy)
# Out:
# 91

# %%
print(type(accuracy))
# Out:
# <class 'float'>

# %%
var = 2

# %%
print(type(var))
# Out:
# <class 'int'>

# %%
var1 = float(var)
print(var1)
print(type(var1))
# Out:
# 2.0
# <class 'float'>

# %%
var1 = str(var)
print(var1)
print(type(var1))
# Out:
# 2
# <class 'str'>

# %% [markdown]
# ## **String**

# %%
string_var = 'HELLO'

# %%
string_var[0]
# Out:
# 'H'

# %%
string_var[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1388/3823733158.py in <cell line: 0>()
# ----> 1 string_var[5]
#
# IndexError: string index out of range

# %%
string_var[-5] # from LHS indexing starts from 0 ,1, 2, 3, 4.. and from RHS indexing starts from -1, -2, -3, -4, -5.
# Out:
# 'H'

# %% [markdown]
# ### **Basic Operations**

# %%
a = 10
b = 2

# %%
a+b
# Out:
# 12

# %%
a*b
# Out:
# 20

# %%
a-b
# Out:
# 8

# %%
a/b
# Out:
# 5.0

# %%
a//b #floor division
# Out:
# 5
