# %% [markdown]
# <a href="https://colab.research.google.com/github/PranavKumar473/DataScience-and-AI/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = "Hello"

# %%
a
# Out:
# 'Hello'

# %%
type(a)
# Out:
# str

# %%
def sum(a,b):
    c = a+b
    print(c)

# %%
sum(10,15)
# Out:
# 25

# %%
def product(a,b):
    c = a * b
    return c

# %%
product(5,2)
# Out:
# 10
